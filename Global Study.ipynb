# %%
#Importing necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
#loading the dataset and reading the head
raw_data =pd.read_csv('survey.csv')
raw_data.head()
# Out:
#           Timestamp  Age  Gender         Country state self_employed  \
# 0  2014-08-27 11:29   37  Female   United States    IL           NaN
# 1  2014-08-27 11:29   44       M   United States    IN           NaN
# 2  2014-08-27 11:29   32    Male          Canada   NaN           NaN
# 3  2014-08-27 11:29   31    Male  United Kingdom   NaN           NaN
# 4  2014-08-27 11:30   31    Male   United States    TX           NaN
#
#   family_history treatment work_interfere    no_employees  ...  \
# 0             No       Yes          Often          25-Jun  ...
# 1             No        No         Rarely  More than 1000  ...
# 2             No        No         Rarely          25-Jun  ...
# 3            Yes       Yes          Often          26-100  ...
# 4             No        No          Never         100-500  ...
#
#                 leave mental_health_consequence phys_health_consequence  \
# 0       Somewhat easy                        No                      No
# ...

# %%
#Data Cleaning 
data=raw_data[raw_data['Gender']==('M')].index
raw_data.drop(data, inplace=True)
raw_data1=raw_data.drop(['comments'], axis=1)
raw_data1.head(100)
# Out:
#             Timestamp  Age  Gender         Country state self_employed  \
# 0    2014-08-27 11:29   37  Female   United States    IL           NaN
# 2    2014-08-27 11:29   32    Male          Canada   NaN           NaN
# 3    2014-08-27 11:29   31    Male  United Kingdom   NaN           NaN
# 4    2014-08-27 11:30   31    Male   United States    TX           NaN
# 5    2014-08-27 11:31   33    Male   United States    TN           NaN
# ..                ...  ...     ...             ...   ...           ...
# 105  2014-08-27 12:23   35    Male   United States    MO            No
# 107  2014-08-27 12:25   28    Male          Brazil   NaN            No
# 108  2014-08-27 12:28   34       m   United States    TN            No
# 109  2014-08-27 12:28   32    Male   United States    WA            No
# 110  2014-08-27 12:29   22    Male   United States    NY            No
#
#     family_history treatment work_interfere no_employees  ...   anonymity  \
# ...

# %%
treatment_yes=raw_data1[raw_data1['treatment'].str.contains("Yes")]
treatment_yes.head()
# Out:
#            Timestamp  Age  Gender         Country state self_employed  \
# 0   2014-08-27 11:29   37  Female   United States    IL           NaN
# 3   2014-08-27 11:29   31    Male  United Kingdom   NaN           NaN
# 6   2014-08-27 11:31   35  Female   United States    MI           NaN
# 8   2014-08-27 11:32   42  Female   United States    IL           NaN
# 10  2014-08-27 11:32   31    Male   United States    OH           NaN
#
#    family_history treatment work_interfere no_employees  ...   anonymity  \
# 0              No       Yes          Often       25-Jun  ...         Yes
# 3             Yes       Yes          Often       26-100  ...          No
# 6             Yes       Yes      Sometimes       05-Jan  ...          No
# 8             Yes       Yes      Sometimes      100-500  ...          No
# 10             No       Yes      Sometimes       25-Jun  ...  Don't know
#
#                  leave mental_health_consequence phys_health_consequence  \
# ...

# %%
mentalhealth_by_location =treatment_yes.groupby(['Country'])['treatment'].count().reset_index(name="of_Employees")
mentalhealth_by_location.sort_values("of_Employees", axis=0, ascending = False)
mentalhealth_by_location.head(100)
# Out:
#          Country  of_Employees
# 0  United States           368

# %%
US_treatment_yes=treatment_yes[treatment_yes['Country'].str.contains("United States")]
US_treatment_yes.head(150)
# Out:
#             Timestamp  Age  Gender        Country state self_employed  \
# 0    2014-08-27 11:29   37  Female  United States    IL           NaN
# 6    2014-08-27 11:31   35  Female  United States    MI           NaN
# 8    2014-08-27 11:32   42  Female  United States    IL           NaN
# 10   2014-08-27 11:32   31    Male  United States    OH           NaN
# 12   2014-08-27 11:33   42  female  United States    CA           NaN
# ..                ...  ...     ...            ...   ...           ...
# 475  2014-08-27 16:15   57    Male  United States    CA            No
# 483  2014-08-27 16:19   29    male  United States    IL            No
# 486  2014-08-27 16:21   28  Female  United States    NY            No
# 487  2014-08-27 16:21   30    Male  United States    CA           Yes
# 493  2014-08-27 16:25   24  Female  United States    CA           Yes
#
#     family_history treatment work_interfere    no_employees  ...   anonymity  \
# ...

# %%
list(US_treatment_yes.columns)
# Out:
# ['Timestamp',
#  'Age',
#  'Gender',
#  'Country',
#  'state',
#  'self_employed',
#  'family_history',
#  'treatment',
#  'work_interfere',
#  'no_employees',
#  'remote_work',
#  'tech_company',
#  'benefits',
#  'care_options',
#  'wellness_program',
#  'seek_help',
#  'anonymity',
#  'leave',
#  'mental_health_consequence',
#  'phys_health_consequence',
#  'coworkers',
#  'supervisor',
#  'mental_health_interview',
#  'phys_health_interview',
#  'mental_vs_physical',
#  'obs_consequence']

# %%
US_treatment_yes=US_treatment_yes.groupby(['benefits'])['benefits'].count().reset_index(name="total")
US_treatment_yes.head(100)
# Out:
#      benefits  total
# 0  Don't know     73
# 1          No     62
# 2         Yes    233

# %%
US_treatment_yes.plot.bar(x='benefits')
